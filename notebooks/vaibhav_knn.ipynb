# %%
# Import libraries
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score

# %%
df = pd.read_csv("final_patent_dataset_balanced.csv")

df.head()
# Out:
#                                           clean_text  novelty tier
# 0  power generation unit oceanographic sensor moo...             0
# 1  novel container design built overrun meter pre...             2
# 2  system rapid bake semiconductor substrate uppe...             2
# 3  electromechanical brake booster disclosed elec...             1
# 4  time pressure dosing fuel additive delivery sy...             1

# %%
df.columns
# Out:
# Index(['clean_text', 'novelty tier'], dtype='object')

# %%
X = df["clean_text"]
y = df["novelty tier"]

# %%
vectorizer = TfidfVectorizer(stop_words="english")

X_vectorized = vectorizer.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_vectorized,
    y,
    test_size=0.2,
    random_state=42
)

# %%
knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test)

# %%
f1 = f1_score(y_test, y_pred, average="macro")

print("Macro F1 Score:", f1)
# Out:
# Macro F1 Score: 0.47591399785544375

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.41      0.48      0.44       240
#            1       0.33      0.31      0.32       236
#            2       0.57      0.42      0.48       264
#            3       0.62      0.71      0.66       260
#
#     accuracy                           0.48      1000
#    macro avg       0.48      0.48      0.48      1000
# weighted avg       0.49      0.48      0.48      1000

# %% [markdown]
# ### KNN Model Evaluation
#
# A KNN classifier was trained on the balanced patent dataset using TF-IDF features.
#
# The model achieved a Macro F1 score on the test dataset. The performance is relatively low because text data produces very high-dimensional feature vectors, which can reduce the effectiveness of distance-based algorithms such as KNN.
